# %% [markdown]
# # PRACTICA 2 Paula González Aceña y Beatriz Ramirez
#
# ### ¡Con todo lo aprendido con Python, vamos a resolver unos ejercicios de Bioinformática!
#
# #### 1.- Concatena las cadenas ATGCC y TCCG

# %%
cadena1 = "ATGCC"
cadena2 = "TCCG"
resultado= cadena1+cadena2
print(resultado)
# Out:
# ATGCCTCCG

# %% [markdown]
# #### 2.- ¿Cuál es la longitud de ATGCGAGT?

# %%
dna="ATGCGAGT"

# %%
len(dna)
# Out:
# 8

# %% [markdown]
# #### 3.- Con la cadena mgXDyTw, ponla en mayúsculas, luego en minúsculas. Extrae su longitud y divide la cadena por la letra "g"

# %%
cadena="mgXDyTw"
cadenamin= cadena.lower()
cadenamayus= cadena.upper()
print(cadenamin)
print(cadenamayus)
# Out:
# mgxdytw
# MGXDYTW

# %%
len(cadena)
# Out:
# 7

# %%
cadena.split(cadena[2])
# Out:
# ['mg', 'DyTw']

# %% [markdown]
# #### 4.- Con la secuencia de aminoácidos vlspadktnv, reemplaza la valina con la tirosina. Pista: usa replace()

# %%
aa = "vlspadktnv"

# %%
aareplace=aa.replace("v","t")
print(aareplace)
# Out:
# tlspadktnt

# %% [markdown]
# #### 5.- Cuenta las valinas de la secuencia original anterior.

# %%
aa = "vlspadktnv"
numero_v=aa.count("v")
print(numero_v)
# Out:
# 2

# %% [markdown]
# #### 6.- Con el diccionario siguiente imprime el valor de BisI y saca el valor de EcoRI con pop(). ¿Qué pasa con el diccionario?

# %%
enzR = {
    'EcoRI':r'GAATTC',
    'AvaII':r'GG(A|T)CC',
    'BisI':r'GC[ATGC]GC'
}

# %%
print(enzR["BisI"])
# Out:
# GC[ATGC]GC

# %%
valor_ecori = enzR.pop("EcoRI")
print(valor_ecori)
# Out:
# GAATTC

# %%
print(enzR)
# Out:
# {'AvaII': 'GG(A|T)CC', 'BisI': 'GC[ATGC]GC'}

# %%
#con el pop se va el EcoRi

# %% [markdown]
# #### 7.- Con la secuencia y la lista siguiente, escribe un algoritmo que cuente el número de veces que aparece un elemento de la lista en la secuencia. Pista: hacer un diccionario para almacenar los resultados puede ser buena idea

# %%
dna = "AATGATGAACGAC" 
dinucleotides = ['AA','AT','AG','AC', 
                 'TA','TT','TG','TC', 
                 'GA','GT','GG','GC', 
                 'CA','CT','CG','CT']

# %%
mi_dict= {"AA":"2","AT":"2","AG":"0","AC":"2","TA":"0","TT":"0","TG":"2","TC":"0","GA":"3","GT":"0","GG":"0","GC":"0","CA":"0","CT":"0","CG":"1","CT":"0"}
mi_dict
# Out:
# {'AA': '2',
#  'AT': '2',
#  'AG': '0',
#  'AC': '2',
#  'TA': '0',
#  'TT': '0',
#  'TG': '2',
#  'TC': '0',
#  'GA': '3',
#  'GT': '0',
#  'GG': '0',
#  'GC': '0',
#  'CA': '0',
#  'CT': '0',
#  'CG': '1'}

# %% [markdown]
# ##### ¿Cuántos counts tiene TC?

# %%
numero_TC = mi_dict["TC"]
print(numero_TC)
# Out:
# 0

# %% [markdown]
# ##### ¿Puedes imprimir los dinuleótidos que tengan counts igual a 2?

# %%
for dinuc, count in mi_dict.items():
    if int(count) == 2:
        print(dinuc, count)
# Out:
# AA 2
# AT 2
# AC 2
# TG 2
